# %%
from dotenv import load_dotenv
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableParallel, RunnableLambda
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# Load environment variables from .env
load_dotenv()

# Create a ChatOpenAI model
model = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# Define prompt template
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert product reviewer."),
        ("human", "List the main features of the product {product_name}."),
    ]
)


# Define pros analysis step
def analyze_pros(features):
    pros_template = ChatPromptTemplate.from_messages(
        [
            ("system", "You are an expert product reviewer."),
            (
                "human",
                "Given these features: {features}, list the pros of these features.",
            ),
        ]
    )
    return pros_template.format_prompt(features=features)


# Define cons analysis step
def analyze_cons(features):
    cons_template = ChatPromptTemplate.from_messages(
        [
            ("system", "You are an expert product reviewer."),
            (
                "human",
                "Given these features: {features}, list the cons of these features.",
            ),
        ]
    )
    return cons_template.format_prompt(features=features) #format_prompt hay invoke đều trả về một list các messages đã được filled in để đưa vào model 


# Combine pros and cons into a final review
def combine_pros_cons(pros, cons):
    return f"Pros:\n{pros}\n\nCons:\n{cons}"


# Simplify branches with LCEL
pros_branch_chain = (
    RunnableLambda(lambda x: analyze_pros(x)) | model | StrOutputParser()
)

cons_branch_chain = (
    RunnableLambda(lambda x: analyze_cons(x)) | model | StrOutputParser()
)

# Create the combined chain using LangChain Expression Language (LCEL)
chain = (
    prompt_template
    | model
    | StrOutputParser()
    | RunnableParallel(branches={"pros": pros_branch_chain, "cons": cons_branch_chain})
    | RunnableLambda(lambda x: combine_pros_cons(x["branches"]["pros"], x["branches"]["cons"]))
)

# Run the chain
result = chain.invoke({"product_name": "MacBook Pro"})

# Output
print(result)
# Out:
# Pros:
# This is a good, balanced overview of the MacBook Pro line. To highlight the *pros* of the features, let's break them down:
#
# **Pros of Consistent Core Features:**
#
# * **Powerful Processors (Apple Silicon):**  The biggest pro is the significant performance leap over Intel-based Macs.  This translates to faster multitasking, smoother video editing, quicker rendering times, and overall improved responsiveness.  The various chip options allow for scalability to meet diverse needs, from casual use to professional workloads.
#
# * **Stunning Retina Displays:**  The vibrant colors, high resolution, and excellent contrast ratios result in a visually stunning and immersive experience.  This is crucial for tasks like photo and video editing, graphic design, and even just casual media consumption.  The ProMotion (120Hz) technology, where available, provides incredibly smooth scrolling and responsiveness, further enhancing the user experience.
#
# * **Robust Build Quality:** The premium materials and construction lead to a durable and long-lasting machine that feels solid and high-end. This translates to a more satisfying user experience and potentially a longer product lifespan.
#
# * **Long Battery Life:**  While usage varies, the generally long battery life allows for extended periods of use without needing to constantly search for a power outlet. This is a significant advantage for productivity and mobility.
#
# * **Excellent Trackpad:**  The large and responsive trackpad offers a precise and intuitive input method, surpassing many competitors.  Gesture support further enhances productivity and ease of use.
#
# * **Keyboard:**  The current keyboard design (post-butterfly keyboard) is generally well-regarded for its comfortable typing experience and reliability.  This improves productivity and reduces the risk of keyboard failures.
#
# * **Connectivity (Thunderbolt/USB4):**  Thunderbolt/USB4 offers high bandwidth and versatile connectivity options. This allows for connecting high-speed peripherals and external displays with ease.  While the number of ports varies, the presence of this standard is a significant advantage.
#
# * **macOS:**  macOS is known for its user-friendly interface, powerful features, and robust security.  The seamless integration with other Apple devices is also a significant benefit for users within the Apple ecosystem.
#
#
# **Highlighting the Pros Related to the "Important Considerations":**
#
# * **Price (despite being expensive):** While expensive, the high price often reflects the superior performance, build quality, and longevity of the MacBook Pro compared to many competitors.  It's a premium product aimed at a premium market.
#
# * **Portability vs. Power:**  The choice between portability and power allows users to select the model that best fits their needs.  The larger models offer incredible power for demanding tasks, while smaller models offer greater portability for those on the go.
#
# * **Specific Needs:**  The wide range of configurations, from processors to RAM and storage, caters to a wide variety of user needs, from casual users to professionals.  This customizability is a significant pro, allowing users to purchase a machine optimized for their specific workflow.
#
#
# In summary, the MacBook Pro offers a compelling combination of powerful performance, stunning visuals, and premium build quality.  The various models cater to different needs and budgets, making it a strong contender for many users, but the specific model choice is crucial for maximizing the pros.
#
#
# Cons:
# The MacBook Pro line, while lauded, has several drawbacks stemming from its core features and design choices:
#
# **Cons related to Core Features:**
#
# * **Powerful Processors (Apple Silicon):** While powerful, the high-end processors significantly inflate the price, making them inaccessible to many.  The performance gains might be negligible for casual users, making the premium unnecessary.  Furthermore,  the reliance on Apple's ecosystem limits repairability and upgrade options.  Repair costs are notoriously high.
#
# * **Stunning Retina Displays:** The high refresh rate (ProMotion) on some models, while beneficial for certain tasks, consumes more battery power.  The reliance on a proprietary display technology means repairs are expensive and limited to Apple authorized service centers.
#
# * **Robust Build Quality:** While durable, the unibody design makes repairs difficult and expensive.  Replacing even minor components often requires professional intervention, and the cost can be prohibitive.  The lack of user-serviceable parts contributes to electronic waste.
#
# * **Long Battery Life:** While generally good, battery life is not exceptionally long, especially under heavy load.  The battery is not user-replaceable, adding to the cost of repair or replacement.  Battery degradation over time is a concern, and replacement is expensive.
#
# * **Excellent Trackpad:** While praised, the large trackpad can be a source of accidental inputs for some users, especially those with smaller hands.  Its integration into the chassis means damage is difficult and expensive to repair.
#
# * **Keyboard:** Although improved from the butterfly keyboard era, the keyboard layout and key travel might not suit all users.  Repairing individual keys is rarely possible, often requiring a full keyboard replacement.
#
# * **Connectivity:** The limited number of ports on some models is a major drawback, forcing reliance on dongles and hubs, adding bulk and cost.  The absence of an SD card reader on some models is a significant inconvenience for professionals who work with large media files.
#
# * **macOS:** While intuitive for many, the macOS ecosystem lock-in limits flexibility and options for users accustomed to other operating systems.  Software compatibility can be a concern, and the cost of macOS software can be high.
#
#
# **Cons related to Important Considerations:**
#
# * **Price:**  MacBook Pros are exceptionally expensive, placing them out of reach for many consumers.  The pricing strategy heavily favors high-margin components and configurations.
#
# * **Portability vs. Power:** The larger models, while powerful, compromise on portability, making them less suitable for users who need a highly mobile device.
#
# * **Specific Needs:**  The high cost necessitates careful consideration of specific needs.  Over-specifying a machine for casual use represents a significant waste of money.  Under-specifying for demanding tasks results in frustration and performance bottlenecks.
#
#
# In summary, while the MacBook Pro offers a premium experience, these inherent drawbacks, especially regarding repairability, cost, and ecosystem lock-in, must be carefully weighed against its advantages.  A potential buyer should critically evaluate their needs and budget before committing to a purchase.
